# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('scrapped-results.csv')


data['Total Votes'] = pd.to_numeric(data['Total Votes'].str.replace(',', ''), errors='coerce')

data['Margin'] = data['Margin'].astype(str).str.replace(',', '')

data['Margin'] = pd.to_numeric(data['Margin'], errors='coerce')

  
plt.figure(figsize=(10, 6))
sns.histplot(data['Total Votes'], bins=30, kde=True)
plt.title('Histogram of Total Votes')
plt.xlabel('Total Votes')
plt.ylabel('Frequency')
plt.show()




top_margins = data.sort_values(by='Margin', ascending=False).head(10)
print("Top Constituencies by Margin of Victory:")
print(top_margins[['Constituency', 'Winning Candidate', 'Margin']])


data.fillna(0, inplace=True)  
data['Total Votes'] = data['Total Votes'].astype(int)
data['Margin'] = data['Margin'].astype(int)
data.drop(columns=['Unnamed: 0'], inplace=True)


plt.figure(figsize=(12, 8))
sns.stripplot(x='Party Name', y='Margin', data=data, jitter=True, size=5, color='blue', alpha=0.5)
plt.xticks(rotation=90)
plt.title('Dot Plot of Winning Margins by Party')
plt.xlabel('Party Name')
plt.ylabel('Margin')
plt.show()
# Out:
# Top Constituencies by Margin of Victory:
#        Constituency      Winning Candidate     Margin
# 888      INDORE(26)        SHANKAR LALWANI  1175092.0
# 112      Dhubri (2)        RAKIBUL HUSSAIN  1012476.0
# 140      Dhubri (2)        RAKIBUL HUSSAIN  1012476.0
# 126      Dhubri (2)        RAKIBUL HUSSAIN  1012476.0
# 154      Dhubri (2)        RAKIBUL HUSSAIN  1012476.0
# 880     VIDISHA(18)  SHIVRAJ SINGH CHOUHAN   821408.0
# 559     Navsari(25)              C R PATIL   773551.0
# 533     Navsari(25)              C R PATIL   773551.0
# 540  Gandhinagar(6)              AMIT SHAH   744716.0
# 514  Gandhinagar(6)              AMIT SHAH   744716.0

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=data, y='Party Name', order=data['Party Name'].value_counts().index)
plt.title('Distribution of Wins by Party')
plt.xlabel('Number of Wins')
plt.ylabel('Party Name')
plt.show()


state_wins = data.groupby(['State', 'Party Name']).size().unstack(fill_value=0)
plt.figure(figsize=(12, 8))
sns.heatmap(state_wins, annot=True, cmap="YlGnBu", fmt="d")
plt.title('State-Wise Winning Analysis')
plt.ylabel('State')
plt.xlabel('Party Name')
plt.show()





top_candidates = data.sort_values(by='Total Votes', ascending=False).head(10)
print("Top Candidates by Votes Received:")
print(top_candidates[['Winning Candidate', 'Total Votes']])


plt.figure(figsize=(10, 6))
sns.scatterplot(x='Total Votes', y='Margin', data=data)
plt.title('Correlation between Total Votes and Margin')
plt.xlabel('Total Votes')
plt.ylabel('Margin')
plt.show()

state_trends = data.groupby('State').size().sort_values(ascending=False)
plt.figure(figsize=(12, 8))
state_trends.plot(kind='bar', color='skyblue')
plt.title('Election Trends by State')
plt.xlabel('State')
plt.ylabel('Number of Wins')
plt.show()


party_wins = data.groupby('Party Name').size()

plt.figure(figsize=(30, 15))
party_wins.plot(kind='pie', autopct='%1.1f%%', colors=plt.cm.Paired(np.arange(len(party_wins))), startangle=90)
plt.title('Party-Wise Winning Distribution')
plt.ylabel('')  
plt.show()



party_performance = data.groupby('Party Name')[['Total Votes', 'Margin']].agg(['mean', 'median', 'sum'])
print("Party Performance Overview:")
print(party_performance)
# Out:
# Top Candidates by Votes Received:
#          Winning Candidate  Total Votes
# 154        RAKIBUL HUSSAIN      1471885
# 112        RAKIBUL HUSSAIN      1471885
# 140        RAKIBUL HUSSAIN      1471885
# 126        RAKIBUL HUSSAIN      1471885
# 888        SHANKAR LALWANI      1226751
# 880  SHIVRAJ SINGH CHOUHAN      1116460
# 725       DR C N MANJUNATH      1079002
# 697       DR C N MANJUNATH      1079002
# 669       DR C N MANJUNATH      1079002
# 486      BRIJMOHAN AGRAWAL      1050351
# Party Performance Overview:
#                                                       Total Votes            \
#                                                              mean    median
# Party Name
# AJSU Party - AJSUP                                  627938.214286  633992.0
# Aam Aadmi Party - AAAP                              330503.461538  322224.0
# Aazad Samaj Party (Kanshi Ram) - ASPKR              530160.637500  509925.5
# All India Majlis-E-Ittehadul Muslimeen - AIMIM      618061.000000  585116.0
# All India Trinamool Congress - AITC                 686933.166667  698753.0
# Apna Dal (Soneylal) - ADAL                          530160.637500  509925.5
# Asom Gana Parishad - AGP                            763337.214286  763779.5
# Bharat Adivasi Party - BHRTADVSIP                   709436.480000  728211.0
# Bharatiya Janata Party - BJP                        621654.179167  608589.0
# Communist Party of India  (Marxist) - CPI(M)        563639.071429  544230.5
# Communist Party of India  (Marxist-Leninist)  (...  529726.350000  534531.5
# Communist Party of India - CPI                      525299.820513  516628.0
# Dravida Munnetra Kazhagam - DMK                     525299.820513  516628.0
# Hindustani Awam Morcha (Secular) - HAMS             529726.350000  534531.5
# Independent - IND                                   515839.706422  533032.0
# Indian National Congress - INC                      590469.353712  572857.0
# Indian Union Muslim League - IUML                   501860.508475  502245.0
# Jammu & Kashmir National Conference - JKN           521969.400000  521836.0
# Janasena Party - JnP                                729684.280000  729699.0
# Janata Dal  (Secular) - JD(S)                       742230.535714  718588.5
# Janata Dal  (United) - JD(U)                        529726.350000  534531.5
# Jharkhand Mukti Morcha - JMM                        627938.214286  633992.0
# Kerala Congress - KEC                               456153.850000  426770.5
# Lok Janshakti Party(Ram Vilas) - LJPRV              529726.350000  534531.5
# Marumalarchi Dravida Munnetra Kazhagam - MDMK       525299.820513  516628.0
# Nationalist Congress Party - NCP                    581296.375000  592221.5
# Nationalist Congress Party – Sharadchandra Pawa...  581296.375000  592221.5
# Rashtriya Janata Dal - RJD                          529726.350000  534531.5
# Rashtriya Lok Dal - RLD                             530160.637500  509925.5
# Rashtriya Loktantrik Party - RLTP                   709436.480000  728211.0
# Revolutionary Socialist Party - RSP                 456153.850000  426770.5
# Samajwadi Party - SP                                530160.637500  509925.5
# Shiromani Akali Dal - SAD                           330503.461538  322224.0
# Shiv Sena (Uddhav Balasaheb Thackrey) - SHSUBT      581296.375000  592221.5
# Shiv Sena - SHS                                     581296.375000  592221.5
# Sikkim Krantikari Morcha - SKM                      164396.000000  164396.0
# Telugu Desam - TDP                                  729684.280000  729699.0
# United People’s Party, Liberal - UPPL               763337.214286  763779.5
# Viduthalai Chiruthaigal Katchi - VCK                525299.820513  516628.0
# Voice of the People Party - VOTPP                   477498.500000  477498.5
# Yuvajana Sramika Rythu Congress Party - YSRCP       729684.280000  729699.0
# Zoram People’s Movement - ZPM                       208552.000000  208552.0
#
#                                                                       Margin  \
#                                                           sum           mean
# Party Name
# AJSU Party - AJSUP                                    8791135  194003.000000
# Aam Aadmi Party - AAAP                                4296545   70516.769231
# Aazad Samaj Party (Kanshi Ram) - ASPKR               42412851   96791.012500
# All India Majlis-E-Ittehadul Muslimeen - AIMIM       10507037  206619.764706
# All India Trinamool Congress - AITC                  28851193  141548.142857
# Apna Dal (Soneylal) - ADAL                           42412851   96791.012500
# Asom Gana Parishad - AGP                             10686721  267453.071429
# Bharat Adivasi Party - BHRTADVSIP                    17735912  170156.280000
# Bharatiya Janata Party - BJP                        298394006  161077.270833
# Communist Party of India  (Marxist) - CPI(M)         47345682  182205.130952
# Communist Party of India  (Marxist-Leninist)  (...   21189054  103835.175000
# Communist Party of India - CPI                       20486693  222254.769231
# Dravida Munnetra Kazhagam - DMK                      20486693  222254.769231
# Hindustani Awam Morcha (Secular) - HAMS              21189054  103835.175000
# Independent - IND                                    56226528  103978.944954
# Indian National Congress - INC                      270434964  147929.506550
# Indian Union Muslim League - IUML                    29609770  187310.576271
# Jammu & Kashmir National Conference - JKN             2609847  186844.600000
# Janasena Party - JnP                                 18242107  205199.320000
# Janata Dal  (Secular) - JD(S)                        20782455  139474.250000
# Janata Dal  (United) - JD(U)                         21189054  103835.175000
# Jharkhand Mukti Morcha - JMM                          8791135  194003.000000
# Kerala Congress - KEC                                 9123077  119169.400000
# Lok Janshakti Party(Ram Vilas) - LJPRV               21189054  103835.175000
# Marumalarchi Dravida Munnetra Kazhagam - MDMK        20486693  222254.769231
# Nationalist Congress Party - NCP                     27902226  109118.458333
# Nationalist Congress Party – Sharadchandra Pawa...   27902226  109118.458333
# Rashtriya Janata Dal - RJD                           21189054  103835.175000
# Rashtriya Lok Dal - RLD                              42412851   96791.012500
# Rashtriya Loktantrik Party - RLTP                    17735912  170156.280000
# Revolutionary Socialist Party - RSP                   9123077  119169.400000
# Samajwadi Party - SP                                 42412851   96791.012500
# Shiromani Akali Dal - SAD                             4296545   70516.769231
# Shiv Sena (Uddhav Balasaheb Thackrey) - SHSUBT       27902226  109118.458333
# Shiv Sena - SHS                                      27902226  109118.458333
# Sikkim Krantikari Morcha - SKM                         164396   80830.000000
# Telugu Desam - TDP                                   18242107  205199.320000
# United People’s Party, Liberal - UPPL                10686721  267453.071429
# Viduthalai Chiruthaigal Katchi - VCK                 20486693  222254.769231
# Voice of the People Party - VOTPP                      954997  263575.500000
# Yuvajana Sramika Rythu Congress Party - YSRCP        18242107  205199.320000
# Zoram People’s Movement - ZPM                          208552   68288.000000
#
#
#                                                       median       sum
# Party Name
# AJSU Party - AJSUP                                  173333.0   2716042
# Aam Aadmi Party - AAAP                               44111.0    916718
# Aazad Samaj Party (Kanshi Ram) - ASPKR               65374.0   7743281
# All India Majlis-E-Ittehadul Muslimeen - AIMIM      172897.0   3512536
# All India Trinamool Congress - AITC                 103374.5   5945022
# Apna Dal (Soneylal) - ADAL                           65374.0   7743281
# Asom Gana Parishad - AGP                            235649.0   3744343
# Bharat Adivasi Party - BHRTADVSIP                   115677.0   4253907
# Bharatiya Janata Party - BJP                        116326.0  77317090
# Communist Party of India  (Marxist) - CPI(M)        173361.5  15305231
# Communist Party of India  (Marxist-Leninist)  (...  100243.5   4153407
# Communist Party of India - CPI                      209409.0   8667936
# Dravida Munnetra Kazhagam - DMK                     209409.0   8667936
# Hindustani Awam Morcha (Secular) - HAMS             100243.5   4153407
# Independent - IND                                    92857.0  11333705
# Indian National Congress - INC                      109111.5  67751714
# Indian Union Muslim League - IUML                   185896.0  11051324
# Jammu & Kashmir National Conference - JKN           188416.0    934223
# Janasena Party - JnP                                220479.0   5129983
# Janata Dal  (Secular) - JD(S)                       113933.5   3905279
# Janata Dal  (United) - JD(U)                        100243.5   4153407
# Jharkhand Mukti Morcha - JMM                        173333.0   2716042
# Kerala Congress - KEC                                93957.5   2383388
# Lok Janshakti Party(Ram Vilas) - LJPRV              100243.5   4153407
# Marumalarchi Dravida Munnetra Kazhagam - MDMK       209409.0   8667936
# Nationalist Congress Party - NCP                     95544.0   5237686
# Nationalist Congress Party – Sharadchandra Pawa...   95544.0   5237686
# Rashtriya Janata Dal - RJD                          100243.5   4153407
# Rashtriya Lok Dal - RLD                              65374.0   7743281
# Rashtriya Loktantrik Party - RLTP                   115677.0   4253907
# Revolutionary Socialist Party - RSP                  93957.5   2383388
# Samajwadi Party - SP                                 65374.0   7743281
# Shiromani Akali Dal - SAD                            44111.0    916718
# Shiv Sena (Uddhav Balasaheb Thackrey) - SHSUBT       95544.0   5237686
# Shiv Sena - SHS                                      95544.0   5237686
# Sikkim Krantikari Morcha - SKM                       80830.0     80830
# Telugu Desam - TDP                                  220479.0   5129983
# United People’s Party, Liberal - UPPL               235649.0   3744343
# Viduthalai Chiruthaigal Katchi - VCK                209409.0   8667936
# Voice of the People Party - VOTPP                   263575.5    527151
# Yuvajana Sramika Rythu Congress Party - YSRCP       220479.0   5129983
# Zoram People’s Movement - ZPM                        68288.0     68288
